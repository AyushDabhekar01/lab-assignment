# %%
tuple=("lion","tiger","elephant")
print(tuple)
# Out:
# ('lion', 'tiger', 'elephant')

# %%
tuple=("lion","tiger","elephant","lion")
print(tuple)
# Out:
# ('lion', 'tiger', 'elephant', 'lion')

# %%
tuple=("lion","tiger","elephant")
print(len(tuple))
# Out:
# 3

# %%
tuple=("lion")
print(type(tuple))
# Out:
# <class 'str'>

# %%
tuple=()
print(type(tuple))
# Out:
# <class 'tuple'>

# %%
tuple1=("lion","tiger","elephant")
tuple2=(1,3,5,7,9)
tuple3=(True,False,False)

# %%
tuple1=("abc",34,True,40,"male")
print(tuple1)
# Out:
# ('abc', 34, True, 40, 'male')

# %% [markdown]
# mytuple=("lion","tiger","elephant")
# print(type(mytuple))

# %%
thistuple=tuple(("lion","tiger","elephant"))
print(thistuple)
# Out:
# ('lion', 'tiger', 'elephant')
