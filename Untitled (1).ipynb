# %%
list=("lion","tiger","elephant")
print(list)
# Out:
# ('lion', 'tiger', 'elephant')

# %%
print(len(list))
# Out:
# 3

# %%
list=["1,2,5,6"]
listt=[True,False,True]
print(type(list))
print(type(listt))
print(type(listt))
# Out:
# <class 'list'>
# <class 'list'>
# <class 'list'>

# %%
newlist=list(("lion","tiger","elephant"))
print(newlist)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 newlist=list(("lion","tiger","elephant"))
#       2 print(newlist)
#
# TypeError: 'list' object is not callable

# %%
list=["lion","tiger","elephant"]
print(list[1])
# Out:
# tiger

# %%
list=["lion","tiger","elephant"]
print(list[-1])
# Out:
# elephant

# %%
listt=[1,3,5,7,9]
print(listt[1:4])
# Out:
# [3, 5, 7]

# %%
listt=[1,3,5,7,9]
print(listt[2:])
# Out:
# [5, 7, 9]

# %%
listt=[1,3,5,7,9]
print(listt[-4:-1])
# Out:
# [3, 5, 7]

# %%
listt=["lion","tiger","elephant"]
if "tiger" in listt:
 print('yes,tiger is part of the animal list')
# Out:
# yes,tiger is part of the animal list

# %%
list=["lion","tiger","elephant"]
list[1]="deer"
print(list)
# Out:
# ['lion', 'deer', 'elephant']

# %%
list=["lion","tiger","elephant"]
list[1:2]=["chetah","deer"]
print(list)
# Out:
# ['lion', 'chetah', 'deer', 'elephant']

# %%
list=["lion","tiger","elephant"]
list[0:3]=["deer"]
print(list)
# Out:
# ['deer']

# %%
list=["lion","tiger","elephant"]
list.insert(1,"deer")
print(list)
# Out:
# ['lion', 'deer', 'tiger', 'elephant']

# %%
list=["lion","tiger","elephant"]
list.append("beaver")
print(list)
# Out:
# ['lion', 'tiger', 'elephant', 'beaver']

# %%
list=["lion","tiger","elephant"]
list1=["cow","sheep","goat"]
list.extend(list1)
print(list)
# Out:
# ['lion', 'tiger', 'elephant', 'cow', 'sheep', 'goat']

# %%
list=["lion","tiger","elephant"]
list.pop()
print(list)
# Out:
# ['lion', 'tiger']

# %%
list=["lion","tiger","elephant"]
del list[1]
print(list)
# Out:
# ['lion', 'elephant']

# %%
list=["lion","tiger","elephant"]
[print(x) for x in list]
# Out:
# lion
# tiger
# elephant
# [None, None, None]

# %%
list=["lion","tiger","elephant"]
list.sort()
print(list)
# Out:
# ['elephant', 'lion', 'tiger']

# %%
thislist=[100,50,65,82,23]
thislist.sort()
print(thislist)
# Out:
# [23, 50, 65, 82, 100]

# %%
print(len(list))
# Out:
# 3
