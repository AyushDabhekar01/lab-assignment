# %%
dict1={'name':"Ayush","roll":"1"}
print(dict1)
# Out:
# {'name': 'Ayush', 'roll': '1'}

# %%
print(len(dict1))
# Out:
# 2

# %%
print(type(dict1))
# Out:
# <class 'dict'>

# %%
dict1=dict(name="rakesh",age=19,country="india")
print(dict1)
# Out:
# {'name': 'rakesh', 'age': 19, 'country': 'india'}

# %%
x=dict1['name']
print(x)
y=dict1.get('roll')
print(y)
# Out:
# Ayush
# 1

# %%
z=dict1.keys()
print(z)
# Out:
# dict_keys(['name', 'roll'])

# %%
m=dict1.values()
print(m)
# Out:
# dict_values(['Ayush', '1'])

# %%
dict1.update({"roll":2})
print(dict1)
dict1["name"]="ayush"
print(dict1)
# Out:
# {'name': 'Ayush', 'roll': 2}
# {'name': 'ayush', 'roll': 2}

# %%
dict1.pop('roll')
print(dict1)
# Out:
# {'name': 'ayush'}
